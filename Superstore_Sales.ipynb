# %% [markdown]
# # EDA SUPERSALES STORE

# %% [markdown]
# # 09.09.2026

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
import pandas as pd

df = pd.read_csv(r"C:\Users\MADHUMATHI\Desktop\Weekly_task\archive.zip")
print("Dataset loaded Successfully")
# Out:
# Dataset loaded Successfully

# %%
df
# Out:
#        Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800    1/3/2023   1/7/2023  Standard Class
# 1           2  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 2           3  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 3           4  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 4           5  US-2023-141817    1/5/2023  1/12/2023  Standard Class
# ...       ...             ...         ...        ...             ...
# 10189   10190  US-2026-143259  12/30/2026   1/3/2027  Standard Class
# 10190   10191  US-2026-115427  12/30/2026   1/3/2027  Standard Class
# 10191   10192  US-2026-156720  12/30/2026   1/3/2027  Standard Class
# 10192   10193  US-2026-143259  12/30/2026   1/3/2027  Standard Class
# 10193   10194  CA-2026-143500  12/30/2026   1/3/2027  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df.head()     # First 5 rows
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800   1/3/2023   1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 2       3  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 3       4  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 4       5  US-2023-141817   1/5/2023  1/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %%
df.head(2)   # First two rows
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800   1/3/2023  1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326   1/4/2023  1/8/2023  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States     Houston  ...       77095
# 1  Phillina Ober  Home Office  United States  Naperville  ...       60540
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
#
#                                         Product Name   Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.448         2
# 1         GBC Standard Plastic Binding Systems Combs   3.540         2
#
#    Discount  Profit
# 0       0.2  5.5512
# 1       0.8 -5.4870
#
# [2 rows x 21 columns]

# %%
df.tail()     # Last Five rows
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 10189   10190  US-2026-143259  12/30/2026  1/3/2027  Standard Class
# 10190   10191  US-2026-115427  12/30/2026  1/3/2027  Standard Class
# 10191   10192  US-2026-156720  12/30/2026  1/3/2027  Standard Class
# 10192   10193  US-2026-143259  12/30/2026  1/3/2027  Standard Class
# 10193   10194  CA-2026-143500  12/30/2026  1/3/2027  Standard Class
#
#       Customer ID      Customer Name    Segment Country/Region           City  \
# 10189    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 10190    EB-13975         Erica Bern  Corporate  United States      Fairfield
# 10191    JM-15580      Jill Matthias   Consumer  United States       Loveland
# 10192    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 10193    HO-15230        Harry Olson   Consumer         Canada  Charlottetown
#
#        ... Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail(3)      # last three rows
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 10191   10192  US-2026-156720  12/30/2026  1/3/2027  Standard Class
# 10192   10193  US-2026-143259  12/30/2026  1/3/2027  Standard Class
# 10193   10194  CA-2026-143500  12/30/2026  1/3/2027  Standard Class
#
#       Customer ID      Customer Name   Segment Country/Region           City  \
# 10191    JM-15580      Jill Matthias  Consumer  United States       Loveland
# 10192    PO-18865  Patrick O'Donnell  Consumer  United States  New York City
# 10193    HO-15230        Harry Olson  Consumer         Canada  Charlottetown
#
#        ... Postal Code Region       Product ID         Category Sub-Category  \
# 10191  ...       80538   West  OFF-FA-10003472  Office Supplies    Fasteners
# 10192  ...       10009   East  TEC-PH-10004774       Technology       Phones
# 10193  ...         C0A   East  OFF-BI-10004040  Office Supplies      Binders
#
#                       Product Name   Sales  Quantity  Discount  Profit
# ...

# %%
# Random 5 rows
df.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9041    9042  US-2026-141873   10/9/2026  10/14/2026  Standard Class
# 2103    2104  US-2024-109603   1/26/2024    2/1/2024  Standard Class
# 8990    8991  US-2026-163818   10/4/2026   10/8/2026  Standard Class
# 7141    7142  US-2026-155824   3/10/2026   3/15/2026  Standard Class
# 3469    3470  US-2024-132486  10/23/2024  10/27/2024    Second Class
#
#      Customer ID      Customer Name      Segment Country/Region  \
# 9041    HG-14845       Harry Greene     Consumer  United States
# 2103    EM-13825  Elizabeth Moffitt    Corporate  United States
# 8990    PS-18970     Paul Stevenson  Home Office  United States
# 7141    KS-16300         Karen Seio    Corporate  United States
# 3469    JF-15355           Jay Fein     Consumer  United States
#
#                City  ... Postal Code Region       Product ID         Category  \
# 9041  New York City  ...       10024   East  FUR-BO-10003034        Furniture
# ...

# %%
df.sample()    # anyone one row as sample
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 4322    4323  US-2025-134138  2/16/2025  2/20/2025  Standard Class
#
#      Customer ID Customer Name   Segment Country/Region        City  ...  \
# 4322    JD-15790    John Dryer  Consumer  United States  Belleville  ...
#
#      Postal Code Region       Product ID   Category Sub-Category  \
# 4322        7109   East  FUR-CH-10001545  Furniture       Chairs
#
#                            Product Name   Sales  Quantity  Discount   Profit
# 4322  Hon Comfortask Task/Swivel Chairs  227.96         2       0.0  36.4736
#
# [1 rows x 21 columns]

# %%
print("Dataset Shape :", df.shape)
print("Number of rows :", df.shape[0])
print("Number of column :", df.shape[1])
print("Total Elements :", df.size)
# Out:
# Dataset Shape : (10194, 21)
# Number of rows : 10194
# Number of column : 21
# Total Elements : 214074

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID              str
# Order Date            str
# Ship Date             str
# Ship Mode             str
# Customer ID           str
# Customer Name         str
# Segment               str
# Country/Region        str
# City                  str
# State/Province        str
# Postal Code           str
# Region                str
# Product ID            str
# Category              str
# Sub-Category          str
# Product Name          str
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  str
#  2   Order Date      10194 non-null  str
#  3   Ship Date       10194 non-null  str
#  4   Ship Mode       10194 non-null  str
#  5   Customer ID     10194 non-null  str
#  6   Customer Name   10194 non-null  str
#  7   Segment         10194 non-null  str
#  8   Country/Region  10194 non-null  str
#  9   City            10194 non-null  str
#  10  State/Province  10194 non-null  str
#  11  Postal Code     10194 non-null  str
#  12  Region          10194 non-null  str
#  13  Product ID      10194 non-null  str
#  14  Category        10194 non-null  str
#  15  Sub-Category    10194 non-null  str
#  16  Product Name    10194 non-null  str
#  17  Sales           10194 non-null  float64
# ...

# %% [markdown]
# # STATISTICAL SUMMARY

# %%
df.describe()
# Out:
#              Row ID         Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5097.500000    228.225854      3.791838      0.155385     28.673417
# std     2942.898656    619.906839      2.228317      0.206249    232.465115
# min        1.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%     2549.250000     17.220000      2.000000      0.000000      1.760800
# 50%     5097.500000     53.910000      3.000000      0.200000      8.690000
# 75%     7645.750000    209.500000      5.000000      0.200000     29.297925
# max    10194.000000  22638.480000     14.000000      0.800000   8399.976000

# %%
numerical_columns = df.select_dtypes(include=np.number).columns

print("Numerical columns :")
print(numerical_columns)
# Out:
# Numerical columns :
# Index(['Row ID', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='str')

# %%
# Categorical columns 

categorical_columns = df.select_dtypes(include="str").columns

print("Categorical columns :")
print(categorical_columns)
# Out:
# Categorical columns :
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country/Region', 'City', 'State/Province',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name'],
#       dtype='str')

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# # Removing null Values

# %%
# Number of rows before removing null values
print("Rows before removing null values :", df.shape[0])

# Removing rows containing null Values
df = df.dropna()

# Number of rows after removing null values
print("Rows after removing null values :", df.shape[0])
# Out:
# Rows before removing null values : 10194
# Rows after removing null values : 10194

# %%
# Verify missing values
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
print("Number of duplicate rows :", df.duplicated().sum())
# Out:
# Number of duplicate rows : 0

# %%
df = df.drop_duplicates()

print("Dataset shape after removing duplicates :", df.shape)
# Out:
# Dataset shape after removing duplicates : (10194, 21)

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"])
df["Ship Date"]=pd.to_datetime(df["Ship Date"])
df[["Order Date","Ship Date"]].dtypes
# Out:
# Order Date    datetime64[us]
# Ship Date     datetime64[us]
# dtype: object

# %%
text_columns = ["Category", "Sub-Category", "Segment"]

for column in text_columns:
    df[column] = (
        df[column]
        .astype(str)
        .str.strip()
        .str.title()
    )

# %%
for column in text_columns:
    print("\n", column)
    print(df[column].unique())
# Out:
#  Category
# <ArrowStringArray>
# ['Office Supplies', 'Furniture', 'Technology']
# Length: 3, dtype: str
#
#  Sub-Category
# <ArrowStringArray>
# [      'Paper',     'Binders',      'Labels',     'Storage',         'Art',
#       'Chairs',   'Fasteners',      'Phones', 'Furnishings', 'Accessories',
#    'Bookcases',   'Envelopes',  'Appliances',      'Tables',    'Supplies',
#     'Machines',     'Copiers']
# Length: 17, dtype: str
#
#  Segment
# <ArrowStringArray>
# ['Consumer', 'Home Office', 'Corporate']
# Length: 3, dtype: str

# %%
print("Final Shape :", df.shape)

print("\nTotal Missing Values :", df.isnull().sum().sum())

print("Total Duplicate Rows :", df.duplicated().sum())

print("\nData Types :")
print(df.dtypes)
# Out:
# Final Shape : (10194, 21)
#
# Total Missing Values : 0
# Total Duplicate Rows : 0
#
# Data Types :
# Row ID                     int64
# Order ID                     str
# Order Date        datetime64[us]
# Ship Date         datetime64[us]
# Ship Mode                    str
# Customer ID                  str
# Customer Name                str
# Segment                      str
# Country/Region               str
# City                         str
# State/Province               str
# Postal Code                  str
# Region                       str
# Product ID                   str
# Category                     str
# Sub-Category                 str
# Product Name                 str
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
numerical_features = [
    "Sales",
    "Quantity", 
    "Discount",
    "Profit",
]

df[numerical_features].describe()
# Out:
#               Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean     228.225854      3.791838      0.155385     28.673417
# std      619.906839      2.228317      0.206249    232.465115
# min        0.444000      1.000000      0.000000  -6599.978000
# 25%       17.220000      2.000000      0.000000      1.760800
# 50%       53.910000      3.000000      0.200000      8.690000
# 75%      209.500000      5.000000      0.200000     29.297925
# max    22638.480000     14.000000      0.800000   8399.976000

# %%
summary = pd.DataFrame({
    "Mean" : df[numerical_features].mean(),
    "Median" : df[numerical_features].median(),
    "Minimum" : df[numerical_features].min(),
    "Maximum" : df[numerical_features].max(),
    "Standard Deviation" : df[numerical_features].std()
})

summary
# Out:
#                 Mean  Median   Minimum    Maximum  Standard Deviation
# Sales     228.225854   53.91     0.444  22638.480          619.906839
# Quantity    3.791838    3.00     1.000     14.000            2.228317
# Discount    0.155385    0.20     0.000      0.800            0.206249
# Profit     28.673417    8.69 -6599.978   8399.976          232.465115

# %% [markdown]
# # Category wise sales

# %%
category_sales = (
    df.groupby("Category")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

category_sales
# Out:
# Category
# Technology         839893.2790
# Furniture          754747.7613
# Office Supplies    731893.3140
# Name: Sales, dtype: float64

# %% [markdown]
# # Category wise Profit

# %%
category_profit = (
    df.groupby("Category")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

category_profit
# Out:
# Category
# Technology         146543.3756
# Office Supplies    126023.4434
# Furniture           19729.9956
# Name: Profit, dtype: float64

# %% [markdown]
# # Sub Categroy wise Sales

# %%
sub_category_sales = (
    df.groupby("Sub-Category")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

sub_category_sales
# Out:
# Sub-Category
# Chairs         335768.2490
# Phones         331842.6400
# Storage        224644.5540
# Tables         208020.1820
# Binders        207354.8810
# Machines       189925.0310
# Accessories    167380.3180
# Copiers        150745.2900
# Bookcases      115361.2043
# Appliances     108213.1850
# Furnishings     95598.1260
# Paper           79540.5380
# Supplies        46725.4980
# Art             27659.0140
# Envelopes       16528.3620
# Labels          12695.0420
# Fasteners        8532.2400
# Name: Sales, dtype: float64

# %% [markdown]
# # Sub Categroy wise Profit

# %%
sub_category_profit = (
    df.groupby("Sub-Category")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

sub_category_profit
# Out:
# Sub-Category
# Copiers        56093.9365
# Phones         45050.8265
# Accessories    41936.6357
# Paper          34511.5070
# Binders        31426.1003
# Chairs         27223.5323
# Storage        21285.1115
# Appliances     18329.4844
# Furnishings    13891.7430
# Envelopes       6988.0247
# Art             6653.1962
# Labels          5572.7780
# Machines        3461.9769
# Fasteners       2428.6358
# Supplies       -1171.3945
# Bookcases      -3632.0736
# Tables        -17753.2061
# Name: Profit, dtype: float64

# %% [markdown]
# # Region Wise Sales

# %%
region_sales = (
    df.groupby("Region")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

region_sales
# Out:
# Region
# West       739813.6085
# East       691828.1680
# Central    503170.6728
# South      391721.9050
# Name: Sales, dtype: float64

# %% [markdown]
# # Region Wise Profit

# %%
region_profit = (
    df.groupby("Region")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

region_profit
# Out:
# Region
# West       110798.8170
# East        94883.2603
# South       46749.4303
# Central     39865.3070
# Name: Profit, dtype: float64

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# # Category-wise Total sales

# %%
plt.figure(figsize=(4, 5))

sns.barplot(
    data = df,
    x = "Category",
    y = "Sales",
    estimator="sum"
)

plt.title("Category-wise Total Sales")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.show()

# %% [markdown]
# # Category wise profit

# %%
plt.figure(figsize=(4, 7))

sns.barplot(
    data = df,
    x = "Category",
    y = "Profit",
    estimator="sum"
)

plt.title("Category-wise Total Sales")
plt.xlabel("Category")
plt.ylabel("Total Profit")

plt.show()

# %% [markdown]
# # Sales Distribution

# %%
plt.figure(figsize=(5, 4))

sns.boxplot(
    data = df,
    y = "Sales",
)

plt.title("Sales Distribution")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# # Profit Box Plot

# %%
plt.figure(figsize=(5, 4))

sns.boxplot(
    data = df,
    y = "Profit",
)

plt.title("Profit Distribution")
plt.ylabel("Profit")

plt.show()

# %% [markdown]
# # Profit Distribution by Category

# %%
plt.figure(figsize=(4, 7))

sns.boxplot(
    data = df,
    x = "Category",
    y = "Profit",
)

plt.title("Category-wise Total Sales")
plt.xlabel("Category")
plt.ylabel("Profit")

plt.show()

# %% [markdown]
# ## Discount vs Profit

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data = df,
    x = "Discount",
    y = "Profit",
)

plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")

plt.show()

# %% [markdown]
# # PROFIT MARGIN

# %% [markdown]
# ## Calculation profit Margin

# %%
df["Profit Margin"] = (df["Profit"] / df["Sales"]) * 100

df[["Sales", "Profit", "Profit Margin"]].head()
# Out:
#      Sales   Profit  Profit Margin
# 0   16.448   5.5512          33.75
# 1    3.540  -5.4870        -155.00
# 2   11.784   4.2717          36.25
# 3  272.736 -64.7748         -23.75
# 4   19.536   4.8840          25.00

# %% [markdown]
# ## Discount vs Profit Margin

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data = df,
    x = "Discount",
    y = "Profit Margin",
)

plt.title("Discount vs Profit Margin")
plt.xlabel("Discount")
plt.ylabel("Profit Margin (%)")

plt.show()

# %% [markdown]
# # CORRELATION ANALYSIS

# %% [markdown]
# ## Correlation
#
# ##### -1 --> Negative Relationship
# ##### 0 --> No Relationship
# ##### 1 --> Positive Relationshp

# %%
numerical_df = df.select_dtypes(include=np.number)

correlation_matrix = numerical_df.corr()

correlation_matrix
# Out:
#                  Row ID     Sales  Quantity  Discount    Profit  Profit Margin
# Row ID         1.000000 -0.008958  0.000502 -0.001474  0.003022       0.001198
# Sales         -0.008958  1.000000  0.198457 -0.027756  0.481460       0.002707
# Quantity       0.000502  0.198457  1.000000  0.007475  0.066145      -0.003830
# Discount      -0.001474 -0.027756  0.007475  1.000000 -0.218882      -0.864821
# Profit         0.003022  0.481460  0.066145 -0.218882  1.000000       0.223224
# Profit Margin  0.001198  0.002707 -0.003830 -0.864821  0.223224       1.000000

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(10, 7))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt="2f",
    cmap="coolwarm"
)

plt.title("Correlation Heatmap of Numerical Attributes")

plt.show()

# %% [markdown]
# # Business Insights
#
# ##### 1. Which category has the highest sales?
# Technology
# ##### 2. Which category has the lowest sales?
# Office Supplies
# ##### 3. Which regions contribute most to sales?
# West
# ##### 4. Which category generates the highest profit?
# Technology
# ##### 5. Which sub-categories have the low or negative profit?
# Tables
# ##### 6. Which regions are most profitable?
# West
# ##### 7. Does profit decrease as discount increases?
# Yes
# ##### 8. Which discount levels have poor profitability?
# 0.8
# ##### 9. Which high-discount transactions generate negative profit?
# 0.7
# ##### 10. Which variables have strong positive correlation?
#
# ##### 11. Which variables have negative correlation?
# ##### 12. Is Discount negatively related to Profit
